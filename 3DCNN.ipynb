# %%
from util import data_generate, train, cnnlstm, cnn3d, DPtrain

import os

import torch
import torch.nn as nn
from torch.utils.data import DataLoader

import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/johnbraswell/miniconda3/envs/ethicalfab/lib/python3.12/site-packages/opacus/accountants/analysis/gdp.py:24: UserWarning: A NumPy version >=1.26.4 and <2.7.0 is required for this version of SciPy (detected version 1.26.0)
#   from scipy import optimize

# %%
# load data
batch_size = 512
path_train = './train_split'
path_test = './test_split'


train_dataset = data_generate.VideoFrameDataset(path_train, 196)
test_dataset = data_generate.VideoFrameDataset(path_test, 196)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# Initialize model, loss function, and optimizer
num_classes = 10  # Set this to the number of classes in your dataset
num_epochs = 20

# %%
model = cnn3d.cnn3d(num_classes)
criterion = nn.CrossEntropyLoss(reduction='none')  # Per-sample loss
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

epoch_results_3dcnn = train.cnn3d(model, train_loader, test_loader, criterion, optimizer, num_epochs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 criterion = nn.CrossEntropyLoss(reduction='none')  # Per-sample loss
#       3 optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# ----> 5 epoch_results_3dcnn = train.cnn3d(model, train_loader, test_loader, criterion, optimizer, num_epochs)
#
# File ~/Desktop/unethical printing/util/train.py:91, in cnn3d(model, train_loader, val_loader, criterion, optimizer, num_epochs, device)
#      87 position_intervals = position_intervals.to(device, non_blocking=True)
#      89 with torch.cuda.amp.autocast(enabled=(device.type == 'cuda')):
#      90     # Forward pass
# ---> 91     outputs = model(frames)
#      93     # Compute loss for each batch based on real frames only.
#      94     expanded_labels = labels.unsqueeze(1).expand(-1, frames.size(1))
#
# File ~/miniconda3/envs/ethicalfab/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ethicalfab/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/unethical printing/util/cnn3d.py:24, in cnn3d.forward(self, x)
#      22 x = x.permute(0, 2, 1, 3, 4)  # Change to [batch_size, 1, max_seq, 32, 32]
#      23 x = self.pool(F.relu(self.bn(self.conv1(x))))
# ---> 24 x = self.pool(F.relu(self.bn(self.conv2(x))))
#      25 x = self.pool(F.relu(self.bn(self.conv3(x))))
#      26 x = x.view(x.size(0), -1)  # Flatten for fully connected layer
#
# File ~/miniconda3/envs/ethicalfab/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/ethicalfab/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/ethicalfab/lib/python3.12/site-packages/torch/nn/modules/conv.py:717, in Conv3d.forward(self, input)
#     716 def forward(self, input: Tensor) -> Tensor:
# --> 717     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/ethicalfab/lib/python3.12/site-packages/torch/nn/modules/conv.py:712, in Conv3d._conv_forward(self, input, weight, bias)
#     700 if self.padding_mode != "zeros":
#     701     return F.conv3d(
#     702         F.pad(
#     703             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    710         self.groups,
#     711     )
# --> 712 return F.conv3d(
#     713     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     714 )
#
# KeyboardInterrupt:
